# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# For better visualization of the plots
from jupyterthemes import jtplot
jtplot.style('onedork')
# Out:
# /Users/harshitsrivastava/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Generating Data

# %%
def geometric_brownian_motion(S0 = 20):
    T = 2
    mu = 0.1
    sigma = 0.01
    dt = 0.01
    N = round(T/dt)
    t = np.linspace(0, T, N)
    time = np.linspace(0, T, N)
    W = np.random.standard_normal(size = N) 
    W = np.cumsum(W)*np.sqrt(dt) ### standard brownian motion ###
    X = (mu-0.5*sigma**2)*t + sigma*W 
    S = S0*np.exp(X) ### geometric brownian motion ###
    plt.plot(time, S)
    plt.xlabel("t", rotation='horizontal')
    plt.ylabel("S", rotation='horizontal')
    plt.show()
    
    return time, S

x_t, a_t = geometric_brownian_motion() # States and actions

# %% [markdown]
# For now, assuming: Asset (x_t) = Price (p_t)

# %%
alph_theta = 0
alph_omega = 0
batch_size = 10

# More parameters to be initialized

# %%
### Calculating rewards:

R = []
for i in range(len(x_t)):
    if i == 0:
        x_init = x_t[i]
        pass
    else:
        r_t = (x_t[i] - x_init) / x_init if x_init else 0
        #print (x_init, x_t[i], r_t)
        x_init = x_t[i]
        #print ("new x_init: ", x_init)
        R.append(r_t)
plt.plot(R)
R = np.array(R)

# %%
# Creating 2-D array of Rewards from N(0, 10)
R = 10.0 * np.random.randn(200, 200) + 0.0
plt.scatter(R[0], R[1])

cov_r = np.cov(R[0], R[1])
cov_r_inv = np.linalg.inv(cov_r)
print ("Covariance matrix of R:\n", cov_r)
print ("Inverse of Covariance matrix of R:\n", cov_r_inv)
# Out:
# Covariance matrix of R:
#  [[101.04873988  -5.21843336]
#  [ -5.21843336  99.38029773]]
# Inverse of Covariance matrix of R:
#  [[0.00992312 0.00052106]
#  [0.00052106 0.01008972]]

# %% [markdown]
# ## Policy $ \pi_\theta (a_t | x_t) $
#
# In order to calculte free energy (Eq B.1), we take one term at a time
# $$ \pi_\theta(a_t|x_t) = \pi_0(a_t|x_t)e^{\beta (\bf {G}_t^\pi (x_t,a_t) - \bf {F}_t^\pi (x_t) )}
# $$
# t = T-1....0
#
# where $ \pi_0: $
# $$ \pi_0(a_t|x_t) = \frac {e^{ \frac {-1}{2} (a_t - \hat{a}(x_t))^T \Sigma_a^{-1} (a_t - \hat{a}(x_t) } }
# {\sqrt{(2\pi)^N |\Sigma_a|}}
# $$
# and $ {\bf G}_t^\pi(x_t, a_t) $:
#
# $$ {\bf G}_t^\pi(x_t, a_t) = {\bf \hat{R}} (x_t, a_t) + \gamma \mathbb{E}_{t,a} \left[ {\bf F}_{t+1}^\pi(x_{t+1})|x_t, a_t \right]
# $$
#
# and $ {\bf F}_t^\pi(x_t) $:
# $$ {\bf F}_t^\pi(x_t) = \frac{1}{\beta} log \sum_{a_t}\pi_0(a_t|x_t) e^{\beta {\bf G}_t^\pi(x_t, a_t)}
# $$

# %% [markdown]
# $ \hat{a} (y_t) = {\bf \hat{A}}_0 + {\bf \hat{A}}_1y_t $

# %%
A_hat_0 = [0]
A_hat_1 = [0]
def a_hat_fn(x_t, t): # x_t not being used right now
    a_hat = A_hat_0 + (A_hat_1*y_t[t]) # Happening at time 't'
    return a_hat

# %%
def prior_policy(a_t, cov_a_inv):
    
    a_hat = a_hat_fn(x_t, t)
    
    term_1 = -0.5 * (a_t - a_hat)**T
    term_2 = cov_a_inv * (a_t - a_hat)
    numer = math.exp(term_1 * term_2)
    
    mag_cov_a = np.linalg.norm(np.cov(a_t))
    denom = np.sqrt( ((2*math.pi)**N)* mag_cov_a )
    
    prior_policy = numer / denom
    
    return prior_policy

# %%
def policy_theta():
    pi_0 = prior_policy(a_t, cov_a_inv)
    pi_theta = pi_0 * math.exp( beta * (G(x_t, a_t) - F(x_T)) )

# %% [markdown]
# ## Conditional Probability $ p_\theta(y_{t+1}|y_t, a_t) $
#
# $$ p_\theta(y_{t+1}|y_t, a_t) = p_z(z_{t+1}|z_t)p_\theta(x_t{x+1}|x_t, a_t) (Eq. 76)$$
#
# where:
# $$ p_z(z_{t+1}|z_t) = \frac {1} {\sqrt{(2\pi)^K |\Sigma_z|}} e^ {-\frac{1}{2}(z_{t+1} - ({\bf I}-\Phi)\circ z_t)^T
# \Sigma_z^{-1} (z_{t+1} - ({\bf I} - \Phi) \circ z_t)} (Eq. 77)
# $$
# and
# $$ p_\theta(x_{t+1}|x_t, a_t) = \frac {1}{\sqrt{(2\pi)^N|\Sigma_r|}} e^{-\frac {1}{2}\Sigma_r^{-1}} (~Eq. 80)$$

# %% [markdown]
# $ z_{t+1} = ({\bf I} - \Phi) \circ z_t + \varepsilon_t^z $
#
# where:
#
# $ \varepsilon_t^z = \mathcal{N}(0, \Sigma_z) $

# %%
# For z_t

def noise(cov_z):
    if np.isnan(cov_z):
        cov_z = 1
    return np.random.normal(0, cov_z)

def z_tplus1(init_z_t = [0]): # Initializing the array with 0
    #for t in range(5): # range to be changed
    print (t)
    I = np.identity(len(init_z_t))
    Phi = np.diag(init_z_t) # Diagonal Matrix of mean reversion rates
    cov_z = np.cov(init_z_t)
    z_t = (I - Phi) * init_z_t + noise(cov_z)
    # z_t = np.multiply((I - phi), init_z_t) + noise(cov_z) ### yet to be tested
    print (z_t)
    #init_z_t = z_t
    return z_t, I, Phi

# %%
# y_t = [x_t,
#       z_t]
assert len(x_t) == len(z_t)
y_t = np.concatenate((x_t, z_t), axis=0)
N = y_t.shape[0]

# %% [markdown]
# $$ p_\theta(x_{t+1}|x_t, a_t) = \frac {1}{\sqrt{(2\pi)^N|\Sigma_r|}} e^{-\frac {1}{2}\Sigma_r^{-1}} (~Eq. 80)$$

# %%
def p_theta(R, N, cov_r, cov_r_inv):
    
    mag_cov_r = np.linalg.norm(cov_r)
    denom = np.sqrt( ((2*math.pi)**N)* mag_cov_r )
    numer = math.exp( -0.5 * cov_r_inv )
    p_theta = numer / denom
    
    return p_theta

# %% [markdown]
# $$ p_z(z_{t+1}|z_t) = \frac {1} {\sqrt{(2\pi)^K |\Sigma_z|}} e^ {-\frac{1}{2}(z_{t+1} - ({\bf I}-\Phi)\circ z_t)^T
# \Sigma_z^{-1} (z_{t+1} - ({\bf I} - \Phi) \circ z_t)} (Eq. 77)
# $$

# %%
def p_z(z_t, T):
    
    K = len(z_t)
    mag_cov_z = np.linalg.norm( np.cov(z_t) )
    denom = np.sqrt( ((2*math.pi)**K) * mag_cov_z )
    
    z_tplus1 = z_tplus1(z_t)
    term_1 = -0.5 * (z_tplus1 - np.multiply( (I - Phi), z_t) ) **T 
    term_2 = cov_z_inv* (z_tplus1 - np.multiply( (I - Phi), z_t) )
    numer = math.exp(term_1 * term_2)
    p_z = numer / denom
    
    return p_z

# %% [markdown]
# ## Variational Distribution $ q_\bar{a}(\bar{a}_t|y_t, \omega) $
# $$ q_\bar{a}(\bar{a}_t|y_t, \omega) = \mathcal{N}(\bar{a}_t|\mu_a(y_t), \Sigma_a) (Eq. 65) $$
#
# where:
# $$ \mu_a(y_t) = \mu_a + \Lambda_a y_t $$
#
# Vector $ \omega $ of parameters includes $ \mu_a, \Lambda_a $ and $ \Sigma_a $
